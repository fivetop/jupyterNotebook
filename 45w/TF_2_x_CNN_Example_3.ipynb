# %% [markdown]
# <a href="https://colab.research.google.com/github/fivetop/romee/blob/main/TF_2_x_CNN_Example_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Basic CNN Architecture (1 Conv / 1 Flatten) 예제
#
# 1. 입력층 개념은 없애고, Conv2D(input_shape=(28,28,1), ...) 형태여야 한다
#
# 2. model.fit(), model.evaluate(), model.predict() 실행시킬때 입력데이터의 형변환을 reshape(-1, 28, 28, 1) 같이 tensor 로 해주어야 한다
#
# 3. index_label_prediction_list 구현

# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape = ', x_train.shape, ' , x_test.shape = ', x_test.shape)
print('t_train.shape = ', t_train.shape, ' , t_test.shape = ', t_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train.shape =  (60000, 28, 28)  , x_test.shape =  (10000, 28, 28)
# t_train.shape =  (60000,)  , t_test.shape =  (10000,)

# %%
# 데이터 출력

plt.figure(figsize=(10,10))

for index in range(25):

    plt.subplot(5, 5, index+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[index], cmap='gray')
    plt.xlabel(str(t_train[index]))

plt.show()

# %%
# sequential model construction

model = Sequential()

# 5 x 5 x 32 필터
model.add(Conv2D(input_shape=(28,28,1), 
                 kernel_size=5, filters=32, 
                 strides=(1,1), activation='relu', use_bias=True, padding='SAME'))

model.add(MaxPool2D(pool_size=(2,2), padding='SAME'))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
# model compile
# one hot encoding 방식이 아니기 때문에, loss=sparse_categorical_crossentropy 정의
# 5*5*32+32 = 832
# 6272 * 10 + 10 = 62730
# X.W + b


model.compile(optimizer=Adam(lr=0.001), 
              loss='sparse_categorical_crossentropy', metrics=['accuracy'])


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 10)                62730
#
# =================================================================
# Total params: 63,562
# Trainable params: 63,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model shape 확인

print(model.input_shape, model.output_shape)
# Out:
# (None, 28, 28, 1) (None, 10)

# %%
# 원래 x_train, x_test 의 shape(차원) 은 (이미지 수, 28, 28) 의 3차원 데이터.
# 이것을 4차원으로 바꾸기 위해 reshape() 을 사용함.
# 가장 처음의 -1 은 batch_size 에 지정된 데이터가 한번에 오는것임.

start_time = datetime.now()

hist = model.fit(x_train.reshape(-1,28,28,1), t_train, 
                 batch_size=50, epochs=50, validation_split=0.2)

end_time = datetime.now()

print('\n\nElapsed Time => ', end_time - start_time)
# Out:
# Epoch 1/50
# 960/960 [==============================] - 14s 4ms/step - loss: 0.2268 - accuracy: 0.9353 - val_loss: 0.0880 - val_accuracy: 0.9759
# Epoch 2/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0737 - accuracy: 0.9782 - val_loss: 0.0682 - val_accuracy: 0.9797
# Epoch 3/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0552 - accuracy: 0.9837 - val_loss: 0.0589 - val_accuracy: 0.9822
# Epoch 4/50
# 960/960 [==============================] - 4s 4ms/step - loss: 0.0435 - accuracy: 0.9872 - val_loss: 0.0549 - val_accuracy: 0.9843
# Epoch 5/50
# 960/960 [==============================] - 3s 4ms/step - loss: 0.0372 - accuracy: 0.9885 - val_loss: 0.0532 - val_accuracy: 0.9850
# Epoch 6/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0315 - accuracy: 0.9897 - val_loss: 0.0529 - val_accuracy: 0.9847
# Epoch 7/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 0.0546 - val_accuracy: 0.9833
# Epoch 8/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.0535 - val_accuracy: 0.9846
# Epoch 9/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0189 - accuracy: 0.9940 - val_loss: 0.0582 - val_accuracy: 0.9847
# Epoch 10/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.0548 - val_accuracy: 0.9861
# Epoch 11/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.0578 - val_accuracy: 0.9847
# Epoch 12/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0584 - val_accuracy: 0.9850
# Epoch 13/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.0651 - val_accuracy: 0.9840
# Epoch 14/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0591 - val_accuracy: 0.9845
# Epoch 15/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0633 - val_accuracy: 0.9860
# Epoch 16/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0696 - val_accuracy: 0.9836
# Epoch 17/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0714 - val_accuracy: 0.9843
# Epoch 18/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0673 - val_accuracy: 0.9856
# Epoch 19/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.0694 - val_accuracy: 0.9850
# Epoch 20/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0684 - val_accuracy: 0.9845
# Epoch 21/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0776 - val_accuracy: 0.9838
# Epoch 22/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0724 - val_accuracy: 0.9866
# Epoch 23/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0791 - val_accuracy: 0.9860
# Epoch 24/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0764 - val_accuracy: 0.9857
# Epoch 25/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0882 - val_accuracy: 0.9827
# Epoch 26/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0789 - val_accuracy: 0.9860
# Epoch 27/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0858 - val_accuracy: 0.9851
# Epoch 28/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.1111 - val_accuracy: 0.9796
# Epoch 29/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0848 - val_accuracy: 0.9854
# Epoch 30/50
# 960/960 [==============================] - 3s 3ms/step - loss: 9.4089e-04 - accuracy: 0.9998 - val_loss: 0.0809 - val_accuracy: 0.9863
# Epoch 31/50
# 960/960 [==============================] - 3s 3ms/step - loss: 1.9334e-04 - accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 0.9868
# Epoch 32/50
# 960/960 [==============================] - 3s 3ms/step - loss: 1.1576e-04 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9869
# Epoch 33/50
# 960/960 [==============================] - 3s 3ms/step - loss: 9.5215e-05 - accuracy: 1.0000 - val_loss: 0.0839 - val_accuracy: 0.9868
# Epoch 34/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0867 - val_accuracy: 0.9852
# Epoch 35/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0890 - val_accuracy: 0.9857
# Epoch 36/50
# 960/960 [==============================] - 3s 3ms/step - loss: 4.8419e-04 - accuracy: 0.9999 - val_loss: 0.0854 - val_accuracy: 0.9862
# Epoch 37/50
# 960/960 [==============================] - 3s 3ms/step - loss: 1.6644e-04 - accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 0.9871
# Epoch 38/50
# 960/960 [==============================] - 3s 3ms/step - loss: 8.2235e-05 - accuracy: 1.0000 - val_loss: 0.0839 - val_accuracy: 0.9872
# Epoch 39/50
# 960/960 [==============================] - 3s 3ms/step - loss: 2.8086e-04 - accuracy: 0.9999 - val_loss: 0.0993 - val_accuracy: 0.9848
# Epoch 40/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0842 - val_accuracy: 0.9859
# Epoch 41/50
# 960/960 [==============================] - 3s 3ms/step - loss: 9.7920e-04 - accuracy: 0.9997 - val_loss: 0.0888 - val_accuracy: 0.9861
# Epoch 42/50
# 960/960 [==============================] - 3s 3ms/step - loss: 8.7575e-04 - accuracy: 0.9997 - val_loss: 0.1006 - val_accuracy: 0.9847
# Epoch 43/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0955 - val_accuracy: 0.9863
# Epoch 44/50
# 960/960 [==============================] - 4s 4ms/step - loss: 2.3769e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9865
# Epoch 45/50
# 960/960 [==============================] - 3s 3ms/step - loss: 5.6530e-05 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9872
# Epoch 46/50
# 960/960 [==============================] - 3s 3ms/step - loss: 3.2481e-05 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9871
# Epoch 47/50
# 960/960 [==============================] - 3s 3ms/step - loss: 2.7410e-05 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9871
# Epoch 48/50
# 960/960 [==============================] - 3s 3ms/step - loss: 2.1888e-05 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 0.9873
# Epoch 49/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.1070 - val_accuracy: 0.9849
# Epoch 50/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0980 - val_accuracy: 0.9849
#
#
# Elapsed Time =>  0:03:22.789665

# %%
# x_test 도 마찬가지로 데이터를 4차원으로 reshape 으로 변환 해주지 않으면 error

model.evaluate(x_test.reshape(-1,28,28,1), t_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0841 - accuracy: 0.9857
# [0.08412280678749084, 0.9857000112533569]

# %%
# index_label_prediction 코드 구현

ret_val = model.predict(x_test.reshape(-1,28,28,1))

print('type(ret_val) = ', type(ret_val), ', ret_val.shape = ', ret_val.shape)

# predict 실행 결과는 softmax 에 의한 확률 결과이므로, argmax 이용해서 10진수로 바꾸어 주어야함

predicted_val = np.argmax(ret_val, axis=1)  # 행 단위로 argmax 실행

prediction_label_comp_val = np.equal(predicted_val, t_test) # 결과가 정답이란 같은가? True or Flase 로 리턴 

# list comprehension 이용하여 index_label_prediction 구현

index_label_prediction_list = [ [index, t_test[index], predicted_val[index] ]  for index, result in enumerate(prediction_label_comp_val)  if result == False ]

print(len(index_label_prediction_list))

print('Accuracy = ', 1 - ( len(index_label_prediction_list) / len(t_test) ))
# Out:
# 313/313 [==============================] - 1s 2ms/step
# type(ret_val) =  <class 'numpy.ndarray'> , ret_val.shape =  (10000, 10)
# 143
# Accuracy =  0.9857

# %%
print(index_label_prediction_list)
# Out:
# [[18, 3, 5], [62, 9, 5], [211, 5, 3], [243, 7, 2], [266, 8, 2], [321, 2, 7], [340, 5, 3], [445, 6, 0], [449, 3, 5], [497, 4, 1], [629, 2, 3], [659, 2, 1], [740, 4, 9], [839, 8, 3], [844, 8, 7], [846, 7, 9], [882, 9, 7], [883, 3, 5], [947, 8, 9], [965, 6, 0], [1014, 6, 5], [1033, 8, 1], [1039, 7, 2], [1112, 4, 6], [1226, 7, 2], [1232, 9, 4], [1242, 4, 9], [1260, 7, 1], [1319, 8, 0], [1326, 7, 2], [1393, 5, 3], [1414, 9, 4], [1425, 8, 4], [1530, 8, 7], [1621, 0, 6], [1709, 9, 3], [1717, 8, 0], [1790, 2, 7], [1878, 8, 3], [1901, 9, 4], [2035, 5, 3], [2053, 4, 9], [2090, 4, 1], [2129, 9, 2], [2130, 4, 9], [2135, 6, 1], [2280, 3, 5], [2293, 9, 4], [2329, 0, 2], [2387, 9, 1], [2406, 9, 8], [2414, 9, 4], [2488, 2, 4], [2534, 3, 5], [2578, 7, 2], [2597, 5, 3], [2630, 4, 9], [2654, 6, 1], [2758, 8, 0], [2760, 9, 4], [2896, 8, 0], [2921, 3, 2], [2939, 9, 5], [2953, 3, 5], [2995, 6, 8], [3012, 8, 4], [3030, 6, 0], [3060, 9, 5], [3073, 1, 2], [3289, 8, 9], [3503, 9, 1], [3520, 6, 4], [3534, 4, 8], [3558, 5, 0], [3626, 8, 3], [3662, 8, 3], [3727, 8, 9], [3751, 7, 2], [3778, 5, 2], [3796, 2, 8], [3808, 7, 8], [3818, 0, 4], [3869, 9, 4], [3906, 1, 3], [4007, 7, 4], [4027, 7, 1], [4065, 0, 2], [4075, 8, 6], [4140, 8, 2], [4176, 2, 7], [4199, 7, 9], [4238, 7, 3], [4256, 3, 2], [4265, 4, 1], [4360, 5, 3], [4443, 3, 1], [4551, 7, 4], [4578, 7, 9], [4731, 8, 3], [4740, 3, 5], [4807, 8, 0], [4823, 9, 4], [4890, 8, 6], [4966, 7, 8], [5246, 7, 2], [5745, 7, 1], [5937, 5, 3], [5955, 3, 8], [5982, 5, 3], [6011, 3, 5], [6071, 9, 3], [6080, 8, 6], [6091, 9, 5], [6166, 9, 3], [6168, 9, 3], [6569, 3, 2], [6574, 2, 6], [6576, 7, 1], [6597, 0, 3], [6625, 8, 2], [6651, 0, 8], [6662, 7, 2], [6755, 8, 7], [6783, 1, 6], [7800, 3, 2], [8183, 8, 5], [8519, 7, 3], [8527, 4, 9], [9009, 7, 2], [9015, 7, 2], [9019, 7, 2], [9024, 7, 2], [9540, 1, 8], [9587, 9, 4], [9637, 7, 3], [9664, 2, 7], [9679, 6, 3], [9698, 6, 5], [9729, 5, 6], [9770, 5, 0], [9839, 2, 3], [9904, 2, 8], [9982, 5, 6]]

# %%
# 임의의 false prediction 이미지 출력

false_data_index = np.random.randint(len(index_label_prediction_list))

#print('len of index_label_prediction_list => ', len(index_label_prediction_list), ', false_data_index => ', false_data_index)

mnist_index = index_label_prediction_list[false_data_index][0]
label = index_label_prediction_list[false_data_index][1]
prediction = index_label_prediction_list[false_data_index][2]

title_str = 'index = ' + str(mnist_index) + ' , label = ' + str(label) + ' , prediction = ' + str(prediction)

img = x_test[mnist_index].reshape(28,28)

plt.title(title_str)
plt.imshow(img, cmap='gray')
plt.show()

# %%
# 데이터 출력

#plt.figure(figsize=(150, 150))
cnt = len(index_label_prediction_list)

for index in range(10):

    mnist_index = index_label_prediction_list[index][0]
    label = index_label_prediction_list[index][1]
    prediction = index_label_prediction_list[index][2]

    title_str = 'index = ' + str(mnist_index) + ' , label = ' + str(label) + ' , prediction = ' + str(prediction)

    img = x_test[mnist_index].reshape(28,28)

    #plt.subplot(150 , 1, index+1)
    plt.title(title_str)
    plt.imshow(img, cmap='gray')
    plt.show()
