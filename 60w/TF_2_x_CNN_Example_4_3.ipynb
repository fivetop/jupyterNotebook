# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape = ', x_train.shape, ' , x_test.shape = ', x_test.shape)
print('t_train.shape = ', t_train.shape, ' , t_test.shape = ', t_test.shape)
# Out:
# x_train.shape =  (60000, 28, 28)  , x_test.shape =  (10000, 28, 28)
# t_train.shape =  (60000,)  , t_test.shape =  (10000,)

# %%
# 데이터 출력

plt.figure(figsize=(10,10))

for index in range(25):

    plt.subplot(5, 5, index+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[index], cmap='gray')
    plt.xlabel(str(t_train[index]))

plt.show()

# %%
# sequential model construction

model = Sequential()

model.add(Conv2D(input_shape=(28,28,1), kernel_size=5, filters=32, strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))
model.add(Dropout(0.25))

model.add(Conv2D(kernel_size=5, filters=64, strides=(1,1), activation='relu', use_bias=True, padding='SAME'))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 28, 28, 32)        832
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 64)        51264
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                31370
# =================================================================
# Total params: 83,466
# Trainable params: 83,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# %%
start_time = datetime.now()

hist = model.fit(x_train, t_train, batch_size=50, epochs=50, validation_data=(x_test, t_test))

end_time = datetime.now()

print('\n\nElapsed Time => ', end_time - start_time)
# Out:
# Epoch 1/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.1499 - accuracy: 0.9551 - val_loss: 0.0441 - val_accuracy: 0.9856
# Epoch 2/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0497 - accuracy: 0.9845 - val_loss: 0.0334 - val_accuracy: 0.9896
# Epoch 3/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0367 - accuracy: 0.9882 - val_loss: 0.0284 - val_accuracy: 0.9901
# Epoch 4/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0283 - accuracy: 0.9907 - val_loss: 0.0258 - val_accuracy: 0.9915
# Epoch 5/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0243 - accuracy: 0.9926 - val_loss: 0.0233 - val_accuracy: 0.9916
# Epoch 6/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.0246 - val_accuracy: 0.9918
# Epoch 7/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.0247 - val_accuracy: 0.9916
# Epoch 8/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.0271 - val_accuracy: 0.9921
# Epoch 9/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0284 - val_accuracy: 0.9916
# Epoch 10/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0291 - val_accuracy: 0.9910
# Epoch 11/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0292 - val_accuracy: 0.9925
# Epoch 12/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0286 - val_accuracy: 0.9922
# Epoch 13/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0241 - val_accuracy: 0.9925
# Epoch 14/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0265 - val_accuracy: 0.9934
# Epoch 15/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0267 - val_accuracy: 0.9922
# Epoch 16/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0383 - val_accuracy: 0.9911
# Epoch 17/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0273 - val_accuracy: 0.9929
# Epoch 18/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0270 - val_accuracy: 0.9931
# Epoch 19/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0303 - val_accuracy: 0.9926
# Epoch 20/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0327 - val_accuracy: 0.9920
# Epoch 21/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0385 - val_accuracy: 0.9921
# Epoch 22/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0330 - val_accuracy: 0.9919
# Epoch 23/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0315 - val_accuracy: 0.9937
# Epoch 24/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0346 - val_accuracy: 0.9925
# Epoch 25/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0341 - val_accuracy: 0.9930
# Epoch 26/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.0357 - val_accuracy: 0.9921
# Epoch 27/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0373 - val_accuracy: 0.9931
# Epoch 28/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.0398 - val_accuracy: 0.9923
# Epoch 29/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0469 - val_accuracy: 0.9920
# Epoch 30/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0391 - val_accuracy: 0.9928
# Epoch 31/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0507 - val_accuracy: 0.9912
# Epoch 32/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0436 - val_accuracy: 0.9928
# Epoch 33/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0502 - val_accuracy: 0.9927
# Epoch 34/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0438 - val_accuracy: 0.9920
# Epoch 35/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0443 - val_accuracy: 0.9921
# Epoch 36/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0474 - val_accuracy: 0.9921
# Epoch 37/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0448 - val_accuracy: 0.9930
# Epoch 38/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0521 - val_accuracy: 0.9925
# Epoch 39/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0542 - val_accuracy: 0.9924
# Epoch 40/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0592 - val_accuracy: 0.9910
# Epoch 41/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0480 - val_accuracy: 0.9930
# Epoch 42/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0502 - val_accuracy: 0.9931
# Epoch 43/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0487 - val_accuracy: 0.9923
# Epoch 44/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.0406 - val_accuracy: 0.9944
# Epoch 45/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0395 - val_accuracy: 0.9933
# Epoch 46/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0384 - val_accuracy: 0.9940
# Epoch 47/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0415 - val_accuracy: 0.9940
# Epoch 48/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0533 - val_accuracy: 0.9927
# Epoch 49/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0506 - val_accuracy: 0.9938
# Epoch 50/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0532 - val_accuracy: 0.9933
#
#
# Elapsed Time =>  0:03:22.331615

# %%
# x_test 도 마찬가지로 데이터를 4차원으로 reshape 으로 변환 해주지 않으면 error

model.evaluate(x_test, t_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0532 - accuracy: 0.9933
# [0.05317416414618492, 0.9933000206947327]

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trend')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='best')
plt.grid()
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trend')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='best')
plt.grid()
plt.show()
