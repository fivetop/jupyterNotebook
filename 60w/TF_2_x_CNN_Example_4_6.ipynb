# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape = ', x_train.shape, ' , x_test.shape = ', x_test.shape)
print('t_train.shape = ', t_train.shape, ' , t_test.shape = ', t_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train.shape =  (60000, 28, 28)  , x_test.shape =  (10000, 28, 28)
# t_train.shape =  (60000,)  , t_test.shape =  (10000,)

# %%
# 데이터 출력

plt.figure(figsize=(10,10))

for index in range(25):

    plt.subplot(5, 5, index+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[index], cmap='gray')
    plt.xlabel(str(t_train[index]))

plt.show()

# %%
# sequential model construction

model = Sequential()

model.add(Conv2D(input_shape=(28,28,1), kernel_size=3, filters=32, strides=(1,1), activation='relu', padding='SAME'))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))


model.add(Conv2D(kernel_size=3, filters=64, strides=(1,1), activation='relu', padding='SAME'))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))


model.add(Conv2D(kernel_size=3, filters=128, strides=(1,1), activation='relu', padding='SAME'))
model.add(MaxPooling2D(pool_size=(2,2), padding='SAME'))


model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 113,162
# Trainable params: 113,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# %%
start_time = datetime.now()

hist = model.fit(x_train, t_train, batch_size=50, epochs=50, validation_data=(x_test, t_test))

end_time = datetime.now()

print('\n\nElapsed Time => ', end_time - start_time)
# Out:
# Epoch 1/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.1436 - accuracy: 0.9550 - val_loss: 0.0566 - val_accuracy: 0.9814
# Epoch 2/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0412 - accuracy: 0.9871 - val_loss: 0.0414 - val_accuracy: 0.9868
# Epoch 3/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0284 - accuracy: 0.9916 - val_loss: 0.0265 - val_accuracy: 0.9913
# Epoch 4/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.0301 - val_accuracy: 0.9908
# Epoch 5/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.0255 - val_accuracy: 0.9918
# Epoch 6/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.0242 - val_accuracy: 0.9928
# Epoch 7/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0268 - val_accuracy: 0.9919
# Epoch 8/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0260 - val_accuracy: 0.9934
# Epoch 9/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0310 - val_accuracy: 0.9929
# Epoch 10/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0371 - val_accuracy: 0.9907
# Epoch 11/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0311 - val_accuracy: 0.9930
# Epoch 12/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0356 - val_accuracy: 0.9915
# Epoch 13/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0397 - val_accuracy: 0.9924
# Epoch 14/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0386 - val_accuracy: 0.9922
# Epoch 15/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.0361 - val_accuracy: 0.9925
# Epoch 16/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0368 - val_accuracy: 0.9929
# Epoch 17/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0415 - val_accuracy: 0.9913
# Epoch 18/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0535 - val_accuracy: 0.9906
# Epoch 19/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0405 - val_accuracy: 0.9927
# Epoch 20/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0406 - val_accuracy: 0.9932
# Epoch 21/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0356 - val_accuracy: 0.9932
# Epoch 22/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0439 - val_accuracy: 0.9917
# Epoch 23/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0359 - val_accuracy: 0.9934
# Epoch 24/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0458 - val_accuracy: 0.9934
# Epoch 25/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0510 - val_accuracy: 0.9937
# Epoch 26/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0523 - val_accuracy: 0.9927
# Epoch 27/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0521 - val_accuracy: 0.9925
# Epoch 28/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0482 - val_accuracy: 0.9927
# Epoch 29/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0566 - val_accuracy: 0.9918
# Epoch 30/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0480 - val_accuracy: 0.9927
# Epoch 31/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0600 - val_accuracy: 0.9921
# Epoch 32/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0616 - val_accuracy: 0.9925
# Epoch 33/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0561 - val_accuracy: 0.9915
# Epoch 34/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0658 - val_accuracy: 0.9913
# Epoch 35/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0608 - val_accuracy: 0.9926
# Epoch 36/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0665 - val_accuracy: 0.9917
# Epoch 37/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0476 - val_accuracy: 0.9922
# Epoch 38/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0439 - val_accuracy: 0.9937
# Epoch 39/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0767 - val_accuracy: 0.9912
# Epoch 40/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0580 - val_accuracy: 0.9934
# Epoch 41/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0703 - val_accuracy: 0.9922
# Epoch 42/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0569 - val_accuracy: 0.9930
# Epoch 43/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0590 - val_accuracy: 0.9926
# Epoch 44/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0620 - val_accuracy: 0.9924
# Epoch 45/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0602 - val_accuracy: 0.9930
# Epoch 46/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 8.2644e-04 - accuracy: 0.9999 - val_loss: 0.0643 - val_accuracy: 0.9929
# Epoch 47/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0630 - val_accuracy: 0.9926
# Epoch 48/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0644 - val_accuracy: 0.9933
# Epoch 49/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0649 - val_accuracy: 0.9935
# Epoch 50/50
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0676 - val_accuracy: 0.9925
#
#
# Elapsed Time =>  0:03:22.332076

# %%
# x_test 도 마찬가지로 데이터를 4차원으로 reshape 으로 변환 해주지 않으면 error

model.evaluate(x_test, t_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0676 - accuracy: 0.9925
# [0.06758669018745422, 0.9925000071525574]

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trend')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='best')
plt.grid()
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trend')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='best')
plt.grid()
plt.show()
